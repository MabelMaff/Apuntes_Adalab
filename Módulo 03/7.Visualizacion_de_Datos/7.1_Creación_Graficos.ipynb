# %% [markdown]
# # Histograma

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Variable_A'], bins=10, kde=False, color="blue")
plt.title('Histograma')
plt.xlabel('Variable_A')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# # Diagrama de Caja

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Category'], y=df['Variable_A'])
plt.title('Diagrama de Caja')
plt.xlabel('Categoría')
plt.ylabel('Variable_A')
plt.show()

# %% [markdown]
# # Violinpot

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['Category'], y=df['Variable_A'])
plt.title('Violinplot')
plt.xlabel('Categoría')
plt.ylabel('Variable_A')
plt.show()

# %% [markdown]
# # Gráfico de Dispersión

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['Variable_A'], y=df['Variable_B'], hue=df['Category'])
plt.title('Gráfico de Dispersión')
plt.xlabel('Variable_A')
plt.ylabel('Variable_B')
plt.show()

# %% [markdown]
# # Gráfico de Regresión

# %%
plt.figure(figsize=(8, 6))
sns.regplot(x='Variable_A', y='Variable_B', data=df)
plt.title('Gráfico de Regresión')
plt.xlabel('Variable_A')
plt.ylabel('Variable_B')
plt.show()

# %% [markdown]
# # Heatmap

# %%
corr_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap')
plt.show()

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Category', data=df, palette='viridis')
plt.title('Countplot')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# # Pie Chart o Diagrama de Quesitos

# %%
count_data = df['Category'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(count_data, labels=count_data.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# # Barplot

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Category', y='Value', data=df, palette='viridis')
plt.title('Barplot')
plt.xlabel('Categoría')
plt.ylabel('Valor')
plt.show()
